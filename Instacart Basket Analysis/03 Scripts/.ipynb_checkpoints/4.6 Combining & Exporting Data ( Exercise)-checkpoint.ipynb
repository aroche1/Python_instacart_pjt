# %% [markdown]
# # Task 4.6

# %% [markdown]
# ## Table of Contents:
#
# ### 01. Importing Libraries
# ### 02. Importing Data Sets as Dataframes
# ### 03. Merging 'df_prods' & 'orders_products_combined' Dataframes
# ### 04. Confirming Results of the Merge
# ### 05. Confirming with Merg-Flags
#
#
# ##### The numbers after the '#' symbol in the comments, represent the step number in the directions of this exercise.

# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Dataframes
# #### - Polishing dataframes and checking shapes

# %%
# Creating path

path = r'/Users/david/Desktop/CF/Data Immersion/Achievement 4 - Python Fundamentals for Data Analysts/07-2022 Instacart Basket Analysis'

# %%
# Checking path

path
# Out:
# '/Users/david/Desktop/CF/Data Immersion/Achievement 4 - Python Fundamentals for Data Analysts/07-2022 Instacart Basket Analysis'

# %%
# Import 'products_checked.csv' 

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', '20_07_22', 'products_checked.csv'), index_col = False)

# %%
# Check 'df_prods'

df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49667       49688       49684
# 49668       49689       49685
# 49669       49690       49686
# 49670       49691       49687
# 49671       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49667          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
# Check shape of 'df_prods'

df_prods.shape
# Out:
# (49672, 6)

# %%
# Redifining 'df_ords'--dropping the 

df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Check redifined 'df_prods'

df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#Check shape of 'df_prods'

df_prods.shape
# Out:
# (49672, 5)

# %%
# 3.- Import 'orders_products_combined.pkl' as 'orders_products_combined'

orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', '21_07_22', 'orders_products_combined.pkl'))

# %%
orders_products_combined
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                11.11484         196
# 1                         8                11.11484       14084
# ...

# %%
# 4.- Check the shape of the imported dataframe

orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
# Removing '_merge' column

orders_products_combined = orders_products_combined.drop(columns = ['_merge'])

# %%
# Check 'orders_products_combined'

orders_products_combined
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2539329        1             1                  2
# 2          2539329        1             1                  2
# 3          2539329        1             1                  2
# 4          2539329        1             1                  2
# ...            ...      ...           ...                ...
# 32434484   2977660   206209            13                  1
# 32434485   2977660   206209            13                  1
# 32434486   2977660   206209            13                  1
# 32434487   2977660   206209            13                  1
# 32434488   2977660   206209            13                  1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                11.11484         196
# 1                         8                11.11484       14084
# ...

# %% [markdown]
# # 03. Merging 'df_prods' & 'orders_products_combined' Dataframes

# %%
# 5.- Determine a suitable way to combine 'orders_products_combined' dataframe with the 'products_checked.csv' data set

# 'df_prods' has 49672 records
# 'orders_products_combined' has 32434489 records
# Merging dataframes is the best method to combine dataframes
# As we are only working with full merge rates, we can just proced to make an Inner Join

df_ords_prods_merged = orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                11.11484         196
# 1                         7                15.00000         196
# ...

# %% [markdown]
# # 04. Confirming Results of the Merge

# %%
# 6.- Confirm the results of the merge using the merge flag.

df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                11.11484         196
# 1                         7                15.00000         196
# ...

# %%
orders_products_merged = df_ords_prods_merged

# %%
orders_products_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                11.11484         196
# 1                         7                15.00000         196
# ...

# %% [markdown]
# # 05. Confirming with Merg-Flags

# %%
# 6.- Confirm the results of the merge using the merge flag--as 'orders_products_merged'

orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# 7.- Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size)

orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', '21_07_22', 'orders_products_merged.pkl'))
